# %%
 pip install negspacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfminer-six
# Out:
# ...
#   Using cached pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# ...
#   Obtaining dependency information for cryptography>=36.0.0 from https://files.pythonhosted.org/packages/d7/78/29d8332bebfe3c2d49a63fb23e1c9fc73a13507b5206b98479fda04c993b/cryptography-41.0.4-cp37-abi3-win_amd64.whl.metadata
#   Using cached cryptography-41.0.4-cp37-abi3-win_amd64.whl.metadata (5.3 kB)
# ...
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/4a/56/572f7f728b20e4d51766e63d7de811e45c7cae727dc1f769caad2973fb52/cffi-1.16.0-cp38-cp38-win_amd64.whl.metadata
# ...
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Using cached cryptography-41.0.4-cp37-abi3-win_amd64.whl (2.7 MB)
# ...
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/181.4 kB 660.6 kB/s eta 0:00:01
# ...

# %%
 pip install scipy
# Out:
# ...
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/b8/8b/31273bf66016be6ad22bb7345c37ff350276cfd46e389a0c2ac5da9d9073/wheel-0.41.2-py3-none-any.whl.metadata
#   Using cached wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.29.0
#     Uninstalling wheel-0.29.0:
#       Successfully uninstalled wheel-0.29.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.1
#     Uninstalling setuptools-67.6.1:
#       Successfully uninstalled setuptools-67.6.1
# ...

# %%
pip install scispacy
# Out:
# ...
#   Obtaining dependency information for scispacy from https://files.pythonhosted.org/packages/9f/1c/f5870c2380f0de7d51ed33bfd5259dd5867251904ac9d01a6688c4a349f6/scispacy-0.5.3-py3-none-any.whl.metadata
#   Using cached scispacy-0.5.3-py3-none-any.whl.metadata (16 kB)
# ...
#   Obtaining dependency information for conllu from https://files.pythonhosted.org/packages/ce/3f/70a1dc5bc536755ec082b806594598a10cfffaf0de978f51d4e0e4fdfa47/conllu-4.5.3-py2.py3-none-any.whl.metadata
#   Using cached conllu-4.5.3-py2.py3-none-any.whl.metadata (19 kB)
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#      ---------------------------------------- 0.0/661.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/661.7 kB ? eta -:--:--
# ...

# %%
 pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bionlp13cg_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bionlp13cg_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.2 MB 330.3 kB/s eta 0:00:37
#      --------------------------------------- 0.0/12.2 MB 281.8 kB/s eta 0:00:44
#      --------------------------------------- 0.1/12.2 MB 328.2 kB/s eta 0:00:38
#      --------------------------------------- 0.1/12.2 MB 469.7 kB/s eta 0:00:26
#      --------------------------------------- 0.1/12.2 MB 481.4 kB/s eta 0:00:26
#       -------------------------------------- 0.2/12.2 MB 492.3 kB/s eta 0:00:25
#       -------------------------------------- 0.2/12.2 MB 626.9 kB/s eta 0:00:20
# ...

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_md-0.5.1.tar.gz
# Out:
# ...
#
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for en-core-sci-md: filename=en_core_sci_md-0.5.1-py3-none-any.whl size=120253157 sha256=f64da861b60d49a3a045663e8d7db2eeafcf3f51a14f6e8ffd0d1d3f9f128fb5
#   Stored in directory: c:\users\arthi\appdata\local\pip\cache\wheels\cd\2d\59\43791dba56f306a2eaa9b510a42699a61e992344837bd25b3f
# Successfully built en-core-sci-md
# ...

# %%
pip install nltk
# Out:
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/7d/38/dcd673b81c2b4930bf39d970decff57ba48e0aee3028364897830ca9cc8e/regex-2023.10.3-cp38-cp38-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.0 kB ? eta -:--:--
#      --------------------------- ---------- 30.7/42.0 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 291.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/269.6 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/269.6 kB 960.0 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/269.6 kB 648.1 kB/s eta 0:00:01
#    ------------------------- -------------- 174.1/269.6 kB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 194.6/269.6 kB 1.2 MB/s eta 0:00:01
# ...

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for en-ner-bc5cdr-md: filename=en_ner_bc5cdr_md-0.5.1-py3-none-any.whl size=120217644 sha256=71548ad8e3b9d9c22957e01648804613c80d606f0e8d80f7b529c2ae6f442315
#   Stored in directory: c:\users\arthi\appdata\local\pip\cache\wheels\a2\b6\73\6e5565b5b65ee473a3e9a18740194c6b1ef4a71857b550459f
# Successfully built en-ner-bc5cdr-md
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for en-core-sci-sm: filename=en_core_sci_sm-0.5.1-py3-none-any.whl size=15870866 sha256=1a25c4f085daac6f7be43827fb4d8eddcda2256679d2b27a7a51c0d4eced51c0
#   Stored in directory: c:\users\arthi\appdata\local\pip\cache\wheels\4a\a5\7a\386418a91842b00f876d34427bbe2d8f8d329f626eab850141
# Successfully built en-core-sci-sm
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import re
from pdfminer.high_level import extract_pages, extract_text

# %%
from negspacy.negation import Negex

# %%
import en_ner_bionlp13cg_md
import en_ner_bc5cdr_md
# Out:
# C:\Users\arthi\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_ner_bionlp13cg_md' (0.5.1) was trained with spaCy v3.4.1 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\arthi\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_ner_bc5cdr_md' (0.5.1) was trained with spaCy v3.4.1 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import scispacy
import spacy
import en_core_sci_md
from spacy import displacy
from collections import Counter
import en_ner_bionlp13cg_md
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker
from collections import OrderedDict
from pprint import pprint
# Out:
# C:\Users\arthi\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_sci_md' (0.5.1) was trained with spaCy v3.4.1 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
bc5_model = "en_ner_bc5cdr_md"
bionlp = "en_ner_bionlp13cg_md"

# %%
text = extract_text("data/cervical-spine-mri-sample-report-1.pdf")

# %%
print(text)
# Out:
# [ NationalRad Sample Neuroradiology Report ]
#
# Imaging Center
# 123 Main Street
# Anywhere, USA 01234
# Phone 123.456.7890
# Fax 123.456.7890
#
# PATIENT:
# DOB:
# FILE #:
# PHYSICIAN:
# EXAM:
# DATE:
#
# JOHN SMITH
# 5/5/1955
# 12345
# REFERRING
# MRI CERVICAL SPINE
# 1/1/2011
#
# CLINICAL INFORMATION
#
# Left neck and shoulder pain for 2 months
#
# COMPARISON
#
# None
#
# CONTRAST
#
# None given
#
# TECHNIQUE
#
# MRI of the cervical spine was obtained with the following sequences: Axial GRE, sagittal T1, T2, and STIR.
#
# FINDINGS
#
# ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to
# muscular spasm.
#
# DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral
# spondylosis.
#
# CORD: Spinal cord is normal in caliber and signal intensity. Cerebellar tonsils are normally located.
#
# ...

# %%
patient_name_pattern = r"DATE:\s*\n(.+?)\n"
file_number_pattern = r"FILE #:\s*(.*)"
clinical_info_pattern = r"CLINICAL INFORMATION\s*(.*?)COMPARISON"
findings_pattern = r"FINDINGS\s*(.*?)IMPRESSION"
impression_pattern = r"IMPRESSION\s*(.*?)\[NationalRad Neuroradiologist\]"

# %%
patient_name = re.search(patient_name_pattern, text, re.DOTALL).group(1).strip()
file_number = re.search(file_number_pattern, text).group(1).strip()
clinical_info = re.search(clinical_info_pattern, text, re.DOTALL).group(1).strip()
findings = re.search(findings_pattern, text, re.DOTALL).group(1).strip()
impression = re.search(impression_pattern, text, re.DOTALL).group(1).strip()

# %%
print("Patient Name:", patient_name)
# Out:
# Patient Name: JOHN SMITH

# %%
print("Clinical info:",clinical_info)
# Out:
# Clinical info: Left neck and shoulder pain for 2 months

# %%
print(findings)
# Out:
# ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to
# muscular spasm.
#
# DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral
# spondylosis.
#
# CORD: Spinal cord is normal in caliber and signal intensity. Cerebellar tonsils are normally located.
#
# BONE MARROW: No destructive bony lesions. There is low T1 signal intensity within the bone marrow
# surrounding the left C4-5 facet joint which may be reactive to facet arthropathy.
#
# Report approved on
#
# NationalRad | Headquartered: Florida | Diagnostic Imaging Services: Nationwide | 877.734.6674 | www.NationalRad.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Page 2 of 2
#
# LEVEL BY LEVEL ANALYSIS:
#
# C2-3: No disc osteophyte complex, spinal canal stenosis, or neural foraminal narrowing.
#
# C3-4: There is a focal 1-2 mm central disc protrusion and mild right uncovertebral joint hypertrophy with
# ...

# %%
print(impression)
# Out:
# 1. Multilevel degenerative disease and facet arthropathy as detailed above, most severe from C4-5 through C6-7.
#
# 2. C6-7 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe bilateral neural
# foraminal narrowing.
#
# 3. C5-6 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe right and mild
# left neural foraminal narrowing.
#
# 4. C4-5 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate right and moderate to
# severe left neural foraminal narrowing. There is left facet arthropathy with surrounding low T1 signal intensity
# within the bone marrow which is likely reactive.

# %%
def display_entities(model,document):
    """
    This function displays word entities

    Parameters:
         model(module): A pretrained model from spaCy(https://spacy.io/models) or ScispaCy(https://allenai.github.io/scispacy/)
         document(str): Document to be processed

    Returns: Image rendering and list of named/unnamed word entities and entity labels
     """
    nlp = model.load()
    doc = nlp(document)
    displacy_image = displacy.render(doc, jupyter=True,style='ent')
    entity_and_label = pprint(set([(X.text, X.label_) for X in doc.ents]))
    return  displacy_image, entity_and_label

# %%
display_entities(en_ner_bionlp13cg_md,impression)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1. Multilevel degenerative disease and facet arthropathy as detailed above, most severe from C4-5 through
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C6-7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
# . <br><br>2.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C6-7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  mild spinal canal stenosis with flattening of the
# ...

# %%
display_entities(en_core_sci_md,impression)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multilevel degenerative disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     facet arthropathy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  as detailed above, most
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     severe
# ...

# %%
display_entities(en_ner_bc5cdr_md,impression)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1. Multilevel degenerative disease and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     facet arthropathy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  as detailed above, most severe from C4-5 through C6-7. <br><br>2. C6-7 mild spinal
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canal stenosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  with flattening of the ventral thecal sac and moderate to severe bilateral neural <br>foraminal narrowing. <br><br>3. C5-6 mild spinal
# ...

# %%
def unified_medical_language_entity_linker(model, document):
    """
    This function links named entities to the Unified Medical Language System UMLS (https://www.nlm.nih.gov/research/umls/)

    Parameters:
         model(module): A pretrained biomedical model from ScispaCy(https://allenai.github.io/scispacy/)
         document(str): Document to be processed

    Returns: Attributes of Named entities accessible in the Unified Medical Language System database
    """
    nlp = model.load()
    
    # Register the UmlsEntityLinker with a name
    linker = UmlsEntityLinker(k=10, max_entities_per_mention=2, name="umls_entity_linker")  # parameters are tunable
    
    # Add the component using its registered name
    nlp.add_pipe("umls_entity_linker")
    
    doc = nlp(document)
    entity = doc.ents
    
    entity = [str(item) for item in entity]               # convert each entity tuple to a list of strings
    entity = str(OrderedDict.fromkeys(entity))            # returns unique entities only
    entity = nlp(entity).ents                             # convert unique entities back to '.ents' object
    
    for entity in entity:
        for umls_ent in entity._.umls_ents:
            print("Entity Name:", entity)
            Concept_Id, Score = umls_ent
            print('Concept_Id = {} Score = {}'.format(Concept_Id, Score))
            print(linker.umls.cui_to_entity[umls_ent[0]])

# %%
from spacy.language import Language

# Register the UmlsEntityLinker as a factory for the English language
@Language.component("umls_entity_linker")
def create_umls_entity_linker(nlp, name="umls_entity_linker"):
    linker = UmlsEntityLinker(k=10, max_entities_per_mention=2)
    
    # Add the linker to the pipeline and return the modified nlp object
    nlp.add_pipe(linker)
    return nlp

# Load the model and create an instance of the pipeline
nlp = en_ner_bc5cdr_md.load()

# Process the document as before
doc = nlp(impression)

# Access and print entity information
for entity in doc.ents:
    for umls_ent in entity._.umls_ents:
        print("Entity Name:", entity)
        Concept_Id, Score = umls_ent
        print('Concept_Id = {} Score = {}'.format(Concept_Id, Score))
        print(linker.umls.cui_to_entity[umls_ent[0]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Negation_detection\Negation model.ipynb Cell 29 line 2
#      <a href='vscode-notebook-cell:/d%3A/Negation_detection/Negation%20model.ipynb#X40sZmlsZQ%3D%3D?line=17'>18</a> # Access and print entity information
#      <a href='vscode-notebook-cell:/d%3A/Negation_detection/Negation%20model.ipynb#X40sZmlsZQ%3D%3D?line=18'>19</a> for entity in doc.ents:
# ---> <a href='vscode-notebook-cell:/d%3A/Negation_detection/Negation%20model.ipynb#X40sZmlsZQ%3D%3D?line=19'>20</a>     for umls_ent in entity._.umls_ents:
#      <a href='vscode-notebook-cell:/d%3A/Negation_detection/Negation%20model.ipynb#X40sZmlsZQ%3D%3D?line=20'>21</a>         print("Entity Name:", entity)
#      <a href='vscode-notebook-cell:/d%3A/Negation_detection/Negation%20model.ipynb#X40sZmlsZQ%3D%3D?line=21'>22</a>         Concept_Id, Score = umls_ent
#
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
a_list = nltk.tokenize.sent_tokenize(impression)

# %%
a_list
# Out:
# ['1.',
#  'Multilevel degenerative disease and facet arthropathy as detailed above, most severe from C4-5 through C6-7.',
#  '2.',
#  'C6-7 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe bilateral neural \nforaminal narrowing.',
#  '3.',
#  'C5-6 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe right and mild \nleft neural foraminal narrowing.',
#  '4.',
#  'C4-5 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate right and moderate to \nsevere left neural foraminal narrowing.',
#  'There is left facet arthropathy with surrounding low T1 signal intensity \nwithin the bone marrow which is likely reactive.']

# %% [markdown]
# Negation detection

# %%
from negspacy.termsets import termset

ts = termset("en_clinical")

print(ts.get_patterns())
# Out:
# {'pseudo_negations': ['no further', 'not able to be', 'not certain if', 'not certain whether', 'not necessarily', 'without any further', 'without difficulty', 'without further', 'might not', 'not only', 'no increase', 'no significant change', 'no change', 'no definite change', 'not extend', 'not cause', 'gram negative', 'not rule out', 'not ruled out', 'not been ruled out', 'not drain', 'no suspicious change', 'no interval change', 'no significant interval change'], 'preceding_negations': ['absence of', 'declined', 'denied', 'denies', 'denying', 'no sign of', 'no signs of', 'not', 'not demonstrate', 'symptoms atypical', 'doubt', 'negative for', 'no', 'versus', 'without', "doesn't", 'doesnt', "don't", 'dont', "didn't", 'didnt', "wasn't", 'wasnt', "weren't", 'werent', "isn't", 'isnt', "aren't", 'arent', 'cannot', "can't", 'cant', "couldn't", 'couldnt', 'never', 'patient was not', 'without indication of', 'without sign of', 'without signs of', 'without any reactions or signs of', 'no co
# ...

# %%
from negspacy.negation import Negex
import spacy

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("negex")
# Out:
# C:\Users\arthi\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_sci_sm' (0.5.1) was trained with spaCy v3.4.1 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
doc = nlp(text)

fmt_str = "{:<22}| {:<10}"
print(fmt_str.format("Entity", "Is negated"))

for entity in doc.ents:
    print(fmt_str.format(entity.text, entity._.negex))
# Out:
# Entity                | Is negated
# NationalRad Sample Neuroradiology Report| 0
# USA                   | 0
# PATIENT               | 0
# Left neck             | 0
# shoulder pain         | 0
# months                | 0
# COMPARISON            | 0
# MRI                   | 0
# cervical spine        | 0
# sequences             | 0
# Axial GRE             | 0
# sagittal T1           | 0
# T2                    | 0
# STIR                  | 0
# FINDINGS              | 0
# cervical lordosis     | 0
# positional            | 0
# muscular spasm        | 0
# DISCS                 | 0
# severe                | 0
# disc space            | 0
# narrowing             | 0
# C4                    | 0
# C6-7 with             | 0
# CORD                  | 0
# Spinal cord           | 0
# caliber               | 0
# signal intensity      | 0
# Cerebellar tonsils    | 0
# bony lesions          | 1
# bone marrow           | 0
# left C4               | 0
# facet joint           | 0
# ...

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("negex", config={"chunk_prefix": ["no"]})

# %%
from negspacy.termsets import termset

ts = termset("en_clinical")

print(ts.get_patterns())
# Out:
# {'pseudo_negations': ['no further', 'not able to be', 'not certain if', 'not certain whether', 'not necessarily', 'without any further', 'without difficulty', 'without further', 'might not', 'not only', 'no increase', 'no significant change', 'no change', 'no definite change', 'not extend', 'not cause', 'gram negative', 'not rule out', 'not ruled out', 'not been ruled out', 'not drain', 'no suspicious change', 'no interval change', 'no significant interval change'], 'preceding_negations': ['absence of', 'declined', 'denied', 'denies', 'denying', 'no sign of', 'no signs of', 'not', 'not demonstrate', 'symptoms atypical', 'doubt', 'negative for', 'no', 'versus', 'without', "doesn't", 'doesnt', "don't", 'dont', "didn't", 'didnt', "wasn't", 'wasnt', "weren't", 'werent', "isn't", 'isnt', "aren't", 'arent', 'cannot', "can't", 'cant', "couldn't", 'couldnt', 'never', 'patient was not', 'without indication of', 'without sign of', 'without signs of', 'without any reactions or signs of', 'no co
# ...

# %%
ts = termset("en_clinical_sensitive")

nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("negex", config={"neg_termset": ts.get_patterns()})

# %%
ts = termset("en_clinical")
ts.add_patterns(
    {
        "preceding_negations":["unable"],
        "following_negations": ["was negative"]
    }
)

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("negex", config={"neg_termset": ts.get_patterns()})

doc = nlp(text)

fmt_str = "{:<10}| {:<10}"
print(fmt_str.format("Entity", "Is negated"))

for entity in doc.ents:
    print(fmt_str.format(entity.text, entity._.negex))
# Out:
# Entity    | Is negated
# NationalRad Sample Neuroradiology Report| 0
# USA       | 0
# PATIENT   | 0
# Left neck | 0
# shoulder pain| 0
# months    | 0
# COMPARISON| 0
# MRI       | 0
# cervical spine| 0
# sequences | 0
# Axial GRE | 0
# sagittal T1| 0
# T2        | 0
# STIR      | 0
# FINDINGS  | 0
# cervical lordosis| 0
# positional| 0
# muscular spasm| 0
# DISCS     | 0
# severe    | 0
# disc space| 0
# narrowing | 0
# C4        | 0
# C6-7 with | 0
# CORD      | 0
# Spinal cord| 0
# caliber   | 0
# signal intensity| 0
# Cerebellar tonsils| 0
# bony lesions| 1
# bone marrow| 0
# left C4   | 0
# facet joint| 0
# facet arthropathy| 0
# NationalRad| 0
# Florida | Diagnostic Imaging| 0
# Nationwide| 0
# | www     | 0
# LEVEL BY LEVEL ANALYSIS| 0
# No disc   | 0
# osteophyte| 1
# spinal canal stenosis| 1
# neural foraminal narrowing| 1
# focal     | 0
# central disc protrusion| 0
# mild right uncovertebral joint hypertrophy| 0
# ventral thecal sac| 0
# mild      | 0
# ...

# %% [markdown]
# Data Annotation

# %%
annotated_data = [
    {"sentence": "Left neck and shoulder pain for 2 months", "negation_status": "Affirmed"},
    {"sentence": "MRI of the cervical spine was obtained with the following sequences: Axial GRE, sagittal T1, T2, and STI", "negation_status": "Affirmed"},
    {"sentence": "ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to muscular spasm.", "negation_status": "Affirmed"},
    {"sentence": "DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral spondylosis.", "negation_status": "Affirmed"},
    {"sentence": "CORD: Spinal cord is normal in caliber and signal intensity. Cerebellar tonsils are normally located.", "negation_status": "Affirmed"},
    {"sentence": "BONE MARROW: No destructive bony lesions. There is low T1 signal intensity within the bone marrow surrounding the left C4-5 facet joint which may be reactive to facet arthropathy.", "negation_status": "Negated"},
    {"sentence": "C2-3: No disc osteophyte complex, spinal canal stenosis, or neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C3-4: There is a focal 1-2 mm central disc protrusion and mild right uncovertebral joint hypertrophy with deformity of the ventral thecal sac with a mild spinal canal stenosis. No significant neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C4-5: There is a diffuse disc osteophyte more prominent on the left and left facet arthropathy with flattening of the ventral thecal sac with a mild spinal canal stenosis and moderate right and moderate to severe left neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C5-6: There is a diffuse disc osteophyte more prominent on the right and mild bilateral facet joint hypertrophy with flattening of the ventral thecal sac with a mild spinal canal stenosis and moderate to severe right and mild left neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C6-7: There is a diffuse disc osteophyte which results in flattening of the ventral thecal sac with a mild spinal canal stenosis and moderate to severe bilateral neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C7-T1: No disc osteophyte complex, spinal canal stenosis, or neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "OTHER FINDINGS: No paraspinal soft tissue mass", "negation_status": "Negated"},
    {"sentence": "Multilevel degenerative disease and facet arthropathy as detailed above, most severe from C4-5 through C6-7.", "negation_status": "Negated"},
    {"sentence": "C6-7 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe bilateral neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C5-6 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate to severe right and mild left neural foraminal narrowing.", "negation_status": "Negated"},
    {"sentence": "C4-5 mild spinal canal stenosis with flattening of the ventral thecal sac and moderate right and moderate to severe left neural foraminal narrowing. There is left facet arthropathy with surrounding low T1 signal intensity within the bone marrow which is likely reactive", "negation_status": "Negated"},
    {"sentence": "69-year-old female with a history of smoking, asthma and bronchitis now with productive cough intermittently for several months", "negation_status": "Affirmed"},
    {"sentence": "CT chest without contrast was performed from the thoracic inlet through the upper abdomen using 5 mm contiguous axial slices and 2-D coronal and sagittal reformats", "negation_status": "Affirmed"},
    {"sentence": "The visualized thyroid gland is unremarkable.", "negation_status": "Negated"},
    {"sentence": "The lungs are hyperinflated.", "negation_status": "Affirmed"},
    {"sentence": "There are scattered foci of septal thickening and groundglass opacity in the bilateral upper lobes with associated tiny cysts.", "negation_status": "Affirmed"},
    {"sentence": "There is an additional tiny focus of reticular nodular density in the super segment of the left lower lobe.", "negation_status": "Affirmed"},
    {"sentence": "The remaining lungs are clear.", "negation_status": "Negated"},
    {"sentence": "There is mild tracheomegaly and bilateral bronchiectasis.", "negation_status": "Affirmed"},
    {"sentence": "The airways are patent.", "negation_status": "Negated"},
    {"sentence": "There is no adenopathy, effusion or pneumothorax.", "negation_status": "Negated"},
    {"sentence": "There is mild cardiomegaly with calcification of the coronary arteries.", "negation_status": "Affirmed"},
    {"sentence": "There is moderate atherosclerosis without aneurysm or leak.", "negation_status": "Affirmed"},
    {"sentence": "The pulmonary arteries are normal in caliber.", "negation_status": "Negated"},
    {"sentence": "There is a moderate hiatal hernia.", "negation_status": "Affirmed"},
    {"sentence": "There is diffuse diverticulosis.", "negation_status": "Affirmed"},
    {"sentence": "The remaining visualized upper abdomen is unremarkable.", "negation_status": "Negated"},
    {"sentence": "There is diffuse spondylosis.", "negation_status": "Affirmed"},
    {"sentence": "There are mild chronic midthoracic compression fractures", "negation_status": "Affirmed"},
    {"sentence": "Nonspecific patchy ground glass opacification and septal thickening bilateral upper lobes and superior segment of left lower lobe likely infectious or inflammatory in etiology.", "negation_status": "Affirmed"},
    {"sentence": "Hyperinflation consistent with COPD.", "negation_status": "Affirmed"},
    {"sentence": "Tracheomegaly and bilateral bronchiectasis.", "negation_status": "Affirmed"},
    {"sentence": "No adenopathy or effusion.", "negation_status": "Negated"},
    {"sentence": "Mild cardiomegaly, diffuse atherosclerosis.", "negation_status": "Affirmed"},
    {"sentence": "Diffuse diverticulosis.", "negation_status": "Affirmed"},
    {"sentence": "Moderate hiatal hernia.", "negation_status": "Affirmed"},
    {"sentence": "Evaluate persistent right elbow pain. Status post fall.", "negation_status": "Affirmed"},
    {"sentence": "Axial T2 axial T1 and coronal T1 axial T1 coronal STIR coronal gradient echo sagittal STIR.", "negation_status": "Affirmed"},
    {"sentence": "FLUID: There is a moderate elbow effusion.", "negation_status": "Affirmed"},
    {"sentence": "There is no osteochondral defect of the capitellum. There is no intraarticular loose fragment or body.", "negation_status": "Negated"},
    {"sentence": "CARTILAGE: Intact.", "negation_status": "Negated"},
    {"sentence": "LIGAMENTS", "negation_status": "Affirmed"},
    {"sentence": "Medial: Mild thickening and increased signal could reflect a low-grade ligamentous sprain or this may be degenerative in origin.", "negation_status": "Affirmed"},
    {"sentence": "Lateral: There is mild proximal thickening as well as increased signal of the lateral ulnar collateral ligament. This could reflect a low-grade ligamentous injury or may also be of a degenerative origin.", "negation_status": "Affirmed"},
    {"sentence": "TENDONS:", "negation_status": "Affirmed"},
    {"sentence": "Common extensor origin: There is common extensor tendinosis of a mild degree.", "negation_status": "Affirmed"},
    {"sentence": "Common flexor origin: Intact.", "negation_status": "Negated"},
    {"sentence": "Anterior: (biceps, brachialis, supinator): No evidence of tendinosis or rupture.", "negation_status": "Negated"},
    {"sentence": "Posterior: (triceps, anconeus): Mild distal triceps tendinosis and peritendinous edema.", "negation_status": "Affirmed"},
    {"sentence": "NERVES:", "negation_status": "Affirmed"},
    {"sentence": "Ulnar nerve, cubital tunnel: Mild enlargement and increased signal. No compressive mass.", "negation_status": "Affirmed"},
    {"sentence": "Radial, median nerve: Intact.", "negation_status": "Negated"},
    {"sentence": "MUSCULATURE: Intact.", "negation_status": "Negated"},
    {"sentence": "BONE MARROW: Evidence of a fracture of the radial head. There is a nondisplaced vertical fracture line in the mid aspect of the radial head with associated marrow edema anteriorly. There is minimal depression of the articular surface anteriorly.", "negation_status": "Affirmed"},
    {"sentence": "Moderate elbow effusion.", "negation_status": "Affirmed"},
    {"sentence": "Evidence of a fracture of the radial head. There is a nondisplaced vertical fracture line in the mid aspect of the radial head with associated marrow edema anteriorly. There is minimal depression of the articular surface anteriorly.", "negation_status": "Affirmed"},
    {"sentence": "Low-grade ligamentous sprains of the medial collateral ligament and lateral ulnar collateral ligament proximally or these alterations could be degenerative in origin.", "negation_status": "Affirmed"},
    {"sentence": "Mild tendinosis of the common extensor tendon origin.", "negation_status": "Affirmed"},
    {"sentence": "Mild distal triceps tendinosis and peritendinous edema.", "negation_status": "Affirmed"},
    {"sentence": "Left medial foot and ankle pain and swelling. Plantar metatarsal pain for 5 weeks. No known trauma", "negation_status": "Affirmed"},
    {"sentence": "Sagittal T1 and STIR, short axis PD and STIR, long axis PD FS imaging is performed through the left midfoot and forefoot without contrast.", "negation_status": "Affirmed"},
    {"sentence": "There is diffuse marrow edema throughout the proximal phalanx of the second digit.", "negation_status": "Affirmed"},
    {"sentence": "There is no definite fracture or cortical disruption identified.", "negation_status": "Negated"},
    {"sentence": "There is mild soft tissue edema and swelling along the plantar aspect of the second toe and second metatarsophalangeal joint.", "negation_status": "Affirmed"},
    {"sentence": "The Lisfranc joint and ligament are normal.", "negation_status": "Negated"},
    {"sentence": "The metatarsal shafts are normal.", "negation_status": "Negated"},
    {"sentence": "The first metatarsophalangeal joint and hallucal sesamoidal complex appear intact.", "negation_status": "Negated"},
    {"sentence": "The flexor and extensor halluces longus tendons are normal.", "negation_status": "Negated"},
    {"sentence": "There is focal soft tissue edema and thinning and attenuation and findings suggestive of a partial-thickness tear involving the medial aspect of the plantar plate of the second metatarsophalangeal joint with a small joint effusion and mild capsulitis.", "negation_status": "Affirmed"},
    {"sentence": "The third, fourth and fifth metatarsophalangeal joints are normal.", "negation_status": "Negated"},
    {"sentence": "No significant intermetatarsal bursitis.", "negation_status": "Negated"},
    {"sentence": "No evidence of Morton's neuroma.", "negation_status": "Negated"},
    {"sentence": "The flexor and extensor tendons and musculature of the midfoot appear normal.", "negation_status": "Negated"},
    {"sentence": "There is focal soft tissue edema and swelling along the plantar aspect of the second metatarsophalangeal joint. Findings are suggestive of a partial-thickness tear/sprain involving the medial aspect of the plantar plate of the second metatarsophalangeal joint. There is a small joint effusion with evidence of mild capsulitis.", "negation_status": "Affirmed"},
    {"sentence": "There is diffuse marrow edema within the proximal phalanx of the second digit. Differential diagnosis includes bone contusion and/or stress related edema. There is no definite fracture identified in this region. Infection seems less likely as an etiology for the marrow edema, recommend clinical correlation with any clinical signs of infection.", "negation_status": "Affirmed"},
    {"sentence": "Fall from a standing height onto an outstretched arm, assess for new versus old fracture, date of injury DATE, ulnar sided hand pain.", "negation_status": "Affirmed"},
    {"sentence": "Coronal T2, STIR and 3-D GRE, axial T1 and STIR, sagittal T2 and STIR sequence imaging is performed through the right hand without contrast", "negation_status": "Affirmed"},
    {"sentence": "There is an intramedullary lesion involving the fifth metacarpal.", "negation_status": "Affirmed"},
    {"sentence": "The fracture extends approximately 2.4 cm in length with bright T2 and intermediate T1 signal.", "negation_status": "Affirmed"},
    {"sentence": "There is endosteal scalloping and minimal expansion.", "negation_status": "Affirmed"},
    {"sentence": "The findings are consistent with an enchondroma.", "negation_status": "Negated"},
    {"sentence": "There appears to be a nondisplaced pathologic fracture through the enchondroma with cortical disruption noted near the junction of the middle and distal thirds of the fifth metacarpal shaft with minimal adjacent periostitis.", "negation_status": "Affirmed"},
    {"sentence": "Mild tenosynovitis of the fourth and fifth flexor tendon sheaths.", "negation_status": "Affirmed"},
    {"sentence": "The flexor and extensor tendons are otherwise normal.", "negation_status": "Negated"},
    {"sentence": "The osseous structures of the right hand are otherwise normal.", "negation_status": "Negated"},
    {"sentence": "The musculature of the right hand is normal.", "negation_status": "Negated"},
    {"sentence": "There is an intramedullary lesion of the fifth metacarpal shaft measuring approximately 2.4 cm in length. The appearance is most typical of an enchondroma and radiographic correlation is advised.", "negation_status": "Affirmed"},
    {"sentence": "There is a nondisplaced transverse fracture involving the fifth metacarpal near the junction of the middle and distal thirds of the metacarpal shaft with minimal adjacent periostitis representing a pathologic fracture. There is adjacent soft tissue edema and this appears to represent an acute injury.", "negation_status": "Affirmed"},
    {"sentence": "Minimal tenosynovitis fourth and fifth digit flexor tendon sheaths.", "negation_status": "Affirmed"},
    {"sentence": "Assess right hip and groin pain for one year. This is associated with locking and the pain is sharp in character. History of playing soccer.", "negation_status": "Affirmed"},
    {"sentence": "None available.", "negation_status": "Negated"},
    {"sentence": "Diluted gadolinium in saline.", "negation_status": "Negated"},
    {"sentence": "After intraarticular injection of diluted gadolinium in saline, axial T1 fat-sat, axial PD fat-sat, coronal T1 fat-sat, sagittal T1 fat-sat, axial oblique PD fat-sat, and coronal bilateral PD fat-sat images were obtained. This was followed by multiple acquisitions in the coronal and sagittal plane sequentially carried out with post processing and color mapping performed in order to obtain a T2 mapping cartigram study.", "negation_status": "Affirmed"},
    {"sentence": "HIP JOINT/LABRUM: Diluted gadolinium contrast was injected into the patient. There is no distinct evidence of an acetabular labral tear. There is no high-grade chondral loss or delamination along the acetabular margin. The labral morphology is maintained. The ligamentum teres shows borderline thickening. The bony anatomy does not reveal prominent acetabular overhang or retroversion. There is bony prominence of the anterior lateral femoral head and neck region as well as mild lack of femoral head and neck offset. This pattern could suggest, in the appropriate clinical setting, findings that may predispose to femoral acetabular impingement.", "negation_status": "Affirmed"},
    {"sentence": "MUSCLES AND TENDONS: The gluteal tendons are intact. The hamstring tendon origins are intact.", "negation_status": "Negated"},
    {"sentence": "BONE MARROW: There is no occult or stress fracture or evidence of AVN.", "negation_status": "Negated"},
    {"sentence": "SYMPHYSIS / SI JOINTS: The bony pelvis is intact including the SI joints and symphysis pubis. With respect to the T2 mapping study, sequential coronal and sagittal images obtained with this technique along with graded color image analysis as well as corresponding graphing, do not reveal significant derangement or elevation of the T2 relaxation times that would indicate the presence of early chondral degeneration and collagen fiber breakdown in this patient at this time.", "negation_status": "Negated"},
    {"sentence": "No evidence of acetabular labral tear or detachment. There is no high-grade chondral loss or delamination.", "negation_status": "Negated"},
    {"sentence": "Mild bone alterations along the femoral head and neck region including bony prominence of the anterolateral femoral head and neck region as well as lack of femoral head and neck offset which could predispose, in the correct clinical setting, to changes of femoroacetabular impingement.", "negation_status": "Affirmed"},
    {"sentence": "No evidence of abnormal elevation of the T2 relaxation times on the T2 mapping study to indicate early chondral degeneration and collage fiber breakdown as discussed above.", "negation_status": "Negated"},
    {"sentence": "Note that the patient had a Ropivacaine pain test carried out; 3 cc of Ropivacaine 0.2% were injected. The patient's pain level was 6/10 prior to injection. There is only minimal diminishment of pain after Ropivacaine injection indicating lack of response to intraarticular Ropivacaine.", "negation_status": "Affirmed"},
    {"sentence": "Note that the alpha angle in this patient is mildly elevated at 61 degrees. The lateral center edge angle of Wiberg is 26 degrees which is within the range of normal.", "negation_status": "Affirmed"},
    {"sentence": "36-year-old male, assess chronic left hip pain.", "negation_status": "Affirmed"},
    {"sentence": "None", "negation_status": "Negated"},
    {"sentence": "Coronal T1 and STIR through the bilateral hips followed by unilateral left hip imaging using axial T1, axial T2 FS, sagittal merge and sagittal T2 imaging.", "negation_status": "Affirmed"},
    {"sentence": "There is mild to moderate chondral thinning noted along the peripheral margin of the left acetabulum with linear fluid signal extending into the substance of the acetabular labrum within the anterosuperolateral quadrant suspicious for a small focal linear pattern tear.", "negation_status": "Affirmed"},
    {"sentence": "There is a cam bump noted along the peripheral margin of the left femoral neck.", "negation_status": "Affirmed"},
    {"sentence": "Small hip effusion present.", "negation_status": "Affirmed"},
    {"sentence": "No fracture, stress fracture or AVN of the left femoral head and neck.", "negation_status": "Negated"},
    {"sentence": "The adductors and hamstring tendons are normal.", "negation_status": "Negated"},
    {"sentence": "There is mild distal gluteus medius insertional tendinosis.", "negation_status": "Affirmed"},
    {"sentence": "No evidence of iliopsoas or greater trochanteric bursitis.", "negation_status": "Negated"},
    {"sentence": "There is soft tissue edema within the left quadratus femoris muscle.", "negation_status": "Affirmed"},
    {"sentence": "There is slight broadening of the right femoral neck with marginal osteophyte formation.", "negation_status": "Affirmed"},
    {"sentence": "There is moderate right hip osteoarthritis with macerated tear of the acetabular labrum within the anterosuperolateral quadrant of the right hip and a small right hip effusion.", "negation_status": "Affirmed"},
    {"sentence": "The adductors, hamstring tendons and gluteus musculature are normal.", "negation_status": "Negated"},
    {"sentence": "There is mild soft tissue edema within the quadratus femoris muscle of the right hip.", "negation_status": "Affirmed"},
    {"sentence": "Visualized osseous pelvis including the pubic symphysis and SI joints are normal.", "negation_status": "Negated"},
    {"sentence": "Findings are suggestive of a cam-type femoral acetabular impingement syndrome of the left hip with a small focal linear pattern tear involving the acetabular labrum within the anterosuperolateral quadrant. There is also mild osteoarthritis of the left hip.", "negation_status": "Affirmed"},
    {"sentence": "There is no fracture, stress fracture or AVN involving the left femoral head and neck.", "negation_status": "Negated"},
    {"sentence": "The right femoral neck demonstrates slight broadening and this may represent the sequela of a developmental dysplasia of the right hip. There is moderate osteoarthritis and findings suggestive of a mixed cam-pincer type femoral acetabular impingement syndrome with a tear of the acetabular labrum.", "negation_status": "Affirmed"},
    {"sentence": "There is soft tissue edema within the quadratus femoris muscles bilaterally. This can be seen with ischiofemoral impingement and clinical correlation is advised.", "negation_status": "Affirmed"},
    {"sentence": "There is mild left gluteus medius insertional tendinosis.", "negation_status": "Affirmed"},
    {"sentence": "Left medial knee pain and swelling for 2 weeks, injured during football, assess for medial meniscal tear, initial visit.", "negation_status": "Affirmed"},
    {"sentence": "Axial PD FS, coronal T1 and STIR, sagittal PD and PD FS imaging is performed through the left knee without contrast", "negation_status": "Affirmed"},
    {"sentence": "FLUID / INTRA-ARTICULAR BODIES: There is a small knee effusion and a small popliteal cyst present. There is circumferential soft tissue edema and swelling at the level the knee most prominent posteriorly.", "negation_status": "Affirmed"},
    {"sentence": "MENISCI:\nMedial: The medial meniscus is normal.", "negation_status": "Negated"},
    {"sentence": "Lateral: The lateral meniscus is normal.", "negation_status": "Negated"},
    {"sentence": "CRUCIATE LIGAMENTS: The anterior cruciate ligament contains mild intrasubstance edema suggestive of a grade 1 sprain but there is no high-grade or full-thickness tear. The PCL is normal.", "negation_status": "Affirmed"},
    {"sentence": "COLLATERAL LIGAMENTS: The medial collateral ligament is normal. The iliotibial band and fibular collateral ligament are normal. There is grade 1 strain/contusion involving the proximal gastrocnemius muscle and the distal biceps femoris muscle.", "negation_status": "Affirmed"},
    {"sentence": "EXTENSOR MECHANISM: The patellar and quadricep tendons are normal.", "negation_status": "Negated"},
    {"sentence": "CARTILAGE:\nPatellofemoral compartment: The patellofemoral articular surfaces are normal.", "negation_status": "Negated"},
    {"sentence": "Medial tibiofemoral compartment: The medial compartment articular surfaces are normal.", "negation_status": "Negated"},
    {"sentence": "Lateral tibiofemoral compartment: The lateral compartment articular surfaces are normal.", "negation_status": "Negated"},
    {"sentence": "BONE MARROW: There are extensive bone contusions involving the distal femur and proximal tibia. There is a nondisplaced Salter II fracture through the distal femoral growth plate with fluid within the growth plate and extensive adjacent marrow edema and bone contusion within the metaphysis. The metaphyseal component of the fracture is noted along the peripheral margin of the lateral femoral condyle with a large subperiosteal hematoma and uplifting and displacement of the periosteum along the posterolateral aspect of the distal femoral metaphysis. There is extensive bone contusion within the epiphyseal region of the proximal tibia. There is a small linear area of low signal abnormality adjacent to the growth plate posteriorly suggestive of a small incomplete nondisplaced transverse fracture through the posterior metaphyseal region of the proximal tibia seen on image 11 of series 9.", "negation_status": "Affirmed"},
    {"sentence": "There are extensive bone contusions of the distal femur and proximal tibia. There is a nondisplaced Salter II fracture through the growth plate of the distal femur with the metaphyseal component of the fracture located along the posterior peripheral aspect of the lateral femoral condyle. There is a subperiosteal hematoma with displacement of the periosteum along the posterolateral aspect of the distal femoral metaphysis.", "negation_status": "Affirmed"},
    {"sentence": "Extensive bone contusion of the proximal tibia with a small incomplete nondisplaced transverse fracture line noted along the posterior margin of the proximal tibial metaphysis.", "negation_status": "Affirmed"},
    {"sentence": "Small knee effusion and popliteal cyst with posterior soft tissue edema and swelling.", "negation_status": "Affirmed"},
    {"sentence": "Grade 1 sprain of the anterior cruciate ligament but no high-grade tear or disruption.", "negation_status": "Affirmed"},
    {"sentence": "Grade 1 strain of the proximal gastrocnemius muscle and distal biceps femoris muscle.", "negation_status": "Affirmed"},
    {"sentence": "No meniscal tear.", "negation_status": "Negated"},
    {"sentence": "The articular surfaces are well preserved.", "negation_status": "Affirmed"},
    {"sentence": "Left knee pain. Semimembranosus bursitis.", "negation_status": "Affirmed"},
    {"sentence": "Left knee ultrasound DATE. Left knee radiographs DATE.", "negation_status": "Affirmed"},
    {"sentence": "Procedure and benefits were explained to the patient and informed consent was signed.", "negation_status": "Affirmed"},
    {"sentence": "Time out procedure was performed to verify patient identity, laterality, and procedure.", "negation_status": "Affirmed"},
    {"sentence": "Sterile preparation with chlorhexidine/alcohol solution was performed.", "negation_status": "Affirmed"},
    {"sentence": "Lidocaine 1% was used for local anesthesia.", "negation_status": "Affirmed"},
    {"sentence": "Under ultrasound guidance, a 20-gauge needle was advanced into the semimembranosus bursa of the left knee using a medial approach and position verified with aspiration of 2 mL of viscous clear yellow fluid.", "negation_status": "Affirmed"},
    {"sentence": "The bursa was flushed twice with anesthetic solution.", "negation_status": "Affirmed"},
    {"sentence": "Then 40 mg Triamcinolone Acetonide, 1 mL Marcaine 0.25% and 1 mL lidocaine 1% were injected within the bursa.", "negation_status": "Affirmed"},
    {"sentence": "Hemostasis was achieved with local compression and a sterile Band-Aid was applied.", "negation_status": "Affirmed"},
    {"sentence": "Patient left the department in good condition with instructions to rest the extremity for a couple of days, use over-the-counter anti-inflammatories if needed and consult with the referring physician if there is increasing pain, swelling or redness.", "negation_status": "Affirmed"},
    {"sentence": "Patient reports complete resolution of left knee pain after aspiration and injection procedure.", "negation_status": "Affirmed"},
    {"sentence": "No immediate complications.", "negation_status": "Negated"},
    {"sentence": "Successful ultrasound-guided aspiration and injection of the left knee semimembranosus bursitis using Triamcinolone Acetonide 40 mg and anesthetic.", "negation_status": "Affirmed"},
    {"sentence": "Low back pain with bilateral lower extremity radiculopathy which is achy and intermittent.", "negation_status": "Affirmed"},
    {"sentence": "None given.", "negation_status": "Negated"},
    {"sentence": "MRI of the lumbar spine was obtained with the following sequences: Axial T2, sagittal T1, T2, and STIR.", "negation_status": "Affirmed"},
    {"sentence": "There is a transitional anatomy with lumbarization of what is designated as the S1 vertebral body with an intervertebral disc at S1-S2. Using this counting designation the last well-formed ribs are at T12 and the conus medullaris ends at L1-L2.", "negation_status": "Affirmed"},
    {"sentence": "There is disc desiccation with moderate disc space narrowing from L1-2 through L5-S1 with prevertebral spondylosis.", "negation_status": "Affirmed"},
    {"sentence": "There a few small Schmorl's nodes identified.", "negation_status": "Affirmed"},
    {"sentence": "Vertebral body heights are otherwise well-maintained without compression fracture.", "negation_status": "Affirmed"},
    {"sentence": "There is no significant bone marrow edema or destructive bony lesions identified.", "negation_status": "Affirmed"},
    {"sentence": "There is diffuse congenital narrowing of the lumbar spinal canal.", "negation_status": "Affirmed"},
    {"sentence": "Note is made of a well-circumscribed 1.6 cm T2 hyperintense lesion within the superior pole of the left kidney, most likely representing a renal cyst.", "negation_status": "Affirmed"},
    {"sentence": "T12-L1: No disc bulge, disc protrusion, spinal canal stenosis, or neural foraminal narrowing.", "negation_status": "Affirmed"},
    {"sentence": "L1-2: There is a mild diffuse disc bulge which results in mild right subarticular recess narrowing without spinal canal or neural foraminal stenosis.", "negation_status": "Affirmed"},
    {"sentence": "L2-3: There is a moderate diffuse disc bulge which results in a mild spinal canal stenosis and mild right and mild to moderate left subarticular recess narrowing with encroachment on the descending left L3 nerve root. There is mild bilateral inferior neural foraminal narrowing.", "negation_status": "Affirmed"},
    {"sentence": "L3-4: There is a moderate diffuse disc bulge and mild facet joint and ligamentum flavum hypertrophy with a mild to moderate spinal canal stenosis and bilateral subarticular recess narrowing with encroachment on the descending bilateral L4 nerve roots. There is mild bilateral inferior neural foraminal narrowing.", "negation_status": "Affirmed"},
    {"sentence": "L4-5: There is a moderate diffuse disc bulge with osteophytic ridging and mild to moderate facet joint and ligamentum flavum hypertrophy with a mild to moderate spinal canal stenosis and mild bilateral subarticular recess narrowing. There is mild right and mild to moderate left inferior neural foraminal narrowing with subtle contact of the exiting left L4 nerve root by the disc osteophyte.", "negation_status": "Affirmed"},
    {"sentence": "L5-S1: There is a diffuse disc osteophyte with a broad-based 3 mm right central disc protrusion with annular tearing and mild facet arthropathy and ligamentum flavum thickening with moderate right and mild left subarticular recess narrowing with mass effect on the descending right S1 nerve root, a mild spinal canal stenosis, and mild to moderate bilateral neural foraminal narrowing with contact of the exiting L5 nerve roots by the disc osteophyte. No paraspinal soft tissue mass is identified.", "negation_status": "Affirmed"},
    {"sentence": "Transitional anatomy with lumbarization of what is designated as the S1 vertebral body. Recommend correlation with plain film imaging for counting purposes prior to any surgical intervention.", "negation_status": "Affirmed"},
    {"sentence": "Multilevel degenerative disc disease and facet arthropathy throughout the lumbar spine as detailed above with diffuse congenital narrowing of the lumbar spinal canal which contributes to spinal canal stenoses.", "negation_status": "Affirmed"},
    {"sentence": "L5-S1 moderate right and mild left subarticular recess narrowing with mass effect on the descending right S1 nerve root, a mild spinal canal stenosis, and mild to moderate bilateral neural foraminal narrowing with contact of the exiting L5 nerve roots by the disc osteophyte.", "negation_status": "Affirmed"},
    {"sentence": "L4-5 mild to moderate spinal canal stenosis, mild bilateral subarticular recess narrowing, and mild right and mild to moderate left inferior neural foraminal narrowing with subtle contact of the left L4 nerve root by a disc osteophyte.", "negation_status": "Affirmed"},
    {"sentence": "L3-4 mild to moderate spinal canal stenosis and bilateral subarticular recess narrowing with encroachment on the descending bilateral L4 nerve roots and mild bilateral neural foraminal narrowing.", "negation_status": "Affirmed"},
    {"sentence": "L2-3 mild spinal canal stenosis and mild right and mild to moderate left subarticular recess narrowing with encroachment on the descending left L3 nerve root and mild bilateral neural foraminal narrowing.", "negation_status": "Affirmed"},
    {"sentence": "Right parotid mass.", "negation_status": "Affirmed"},
    {"sentence": "Comparison CT head/upper neck dated 1/6/2015.", "negation_status": "Negated"},
    {"sentence": "6 cc of Gadavist administered without complication", "negation_status": "Affirmed"},
    {"sentence": "Axial, sagittal and coronal T1-weighted, sagittal, axial and coronal fat saturated T2-weighted images were obtained. Following contrast administration, sagittal, axial and coronal T1-weighted sequences were also obtained.", "negation_status": "Affirmed"},
    {"sentence": "Evaluation of the neck reveals a somewhat heterogeneous but well defined lobulated mass within the superficial lobe of the anterior right parotid gland.", "negation_status": "Affirmed"},
    {"sentence": "The mass demonstrates a rounded focus of signal prolongation with enhancement.", "negation_status": "Affirmed"},
    {"sentence": "The mass measures approximately 0.8 x 0.9 x 0.7 CM (anterior-posterior by transverse by superior-inferior).", "negation_status": "Affirmed"},
    {"sentence": "This appears similar to that noted on the prior CT.", "negation_status": "Affirmed"},
    {"sentence": "The mass just abuts the retromandibular vein, patent and medial to the right parotid duct.", "negation_status": "Affirmed"},
    {"sentence": "The mass is most consistent with a benign pleomorphic adenoma.", "negation_status": "Affirmed"},
    {"sentence": "No left-sided parotid mass is seen.", "negation_status": "Negated"},
    {"sentence": "Right and left submandibular glands are unremarkable.", "negation_status": "Affirmed"},
    {"sentence": "The mucosal surfaces of the upper aerodigestive tract appear symmetric and unremarkable.", "negation_status": "Affirmed"},
    {"sentence": "The larynx is intact.", "negation_status": "Affirmed"},
    {"sentence": "The nasopharynx is symmetric without distinct lesion.", "negation_status": "Affirmed"},
    {"sentence": "The tongue and tongue base appear symmetric and unremarkable.", "negation_status": "Affirmed"},
    {"sentence": "The median raphe is midline.", "negation_status": "Affirmed"},
    {"sentence": "The thyroid gland appears symmetric without distinct nodule.", "negation_status": "Affirmed"},
    {"sentence": "No pathologically enlarged lymph nodes are found.", "negation_status": "Affirmed"},
    {"sentence": "The visualized lymph nodes demonstrate no central necrosis or extranodal extension.", "negation_status": "Affirmed"},
    {"sentence": "The right and left faucial tonsil is symmetric and unremarkable.", "negation_status": "Affirmed"},
    {"sentence": "The lingual tonsillar tissue appears symmetric and of normal volume.", "negation_status": "Affirmed"},
    {"sentence": "The posterior nasopharyngeal lymphoid tissue does not appear enlarged.", "negation_status": "Affirmed"},
    {"sentence": "Evaluation of the paranasal sinuses reveals no significant sinus inflammatory disease.", "negation_status": "Affirmed"},
    {"sentence": "No air-fluid levels are noted.", "negation_status": "Affirmed"},
    {"sentence": "The central skull base is intact.", "negation_status": "Affirmed"},
    {"sentence": "The central petrous temporal bones and mastoids remain clear.", "negation_status": "Affirmed"},
    {"sentence": "The visualized base of brain appears unremarkable.", "negation_status": "Affirmed"},
    {"sentence": "Cervical spondylosis is noted, most notable for a broad-based disc bulge and dorsal osteophytic ridge at the C5/6 level with a C6/7 level focal 2 mm central disc protrusion and dorsal osteophytic ridging, resulting in mild central spinal stenosis. Mild foraminal narrowing also evident bilaterally.", "negation_status": "Affirmed"},
    {"sentence": "The lung apices are clear.", "negation_status": "Affirmed"},
    {"sentence": "Macroadenoma with no priors available for comparison.", "negation_status": "Negated"},
    {"sentence": "15 cc MultiHance intravenously.", "negation_status": "Affirmed"},
    {"sentence": "Sagittal T2, axial T2 flair, coronal T2, and post gadolinium axial T1 weighted sequences were obtained through the whole brain.", "negation_status": "Affirmed"},
    {"sentence": "High-resolution coronal T1 and T2 sagittal T1, post gadolinium coronal dynamic, and post gadolinium coronal and sagittal T1 weighted sequences were obtained through the sella.", "negation_status": "Affirmed"},
    {"sentence": "There is a large sellar and suprasellar mass with areas of internal cystic change or necrosis within the central and right lateral aspect of the mass.", "negation_status": "Affirmed"},
    {"sentence": "The mass measures approximately 2.0 x 2.0 x 1.4 cm in size (craniocaudal by transverse by AP) with mass effect on the right greater than left optic chiasm and cisternal segment of the right optic nerve.", "negation_status": "Affirmed"},
    {"sentence": "The pituitary stalk appears to be deviated to the right.", "negation_status": "Affirmed"},
    {"sentence": "The mass appears to invade into the medial aspect of the left and likely the right cavernous sinuses.", "negation_status": "Affirmed"},
    {"sentence": "Cavernous carotid flow voids appear normal in caliber bilaterally.", "negation_status": "Affirmed"},
    {"sentence": "There is associated expansion of the sella.", "negation_status": "Affirmed"},
    {"sentence": "The brain parenchyma is normal in signal intensity.", "negation_status": "Affirmed"},
    {"sentence": "The ventricles and sulci are normal in size and position.", "negation_status": "Affirmed"},
    {"sentence": "There is no abnormal intraparenchymal enhancement.", "negation_status": "Negated"},
    {"sentence": "No evidence of intracranial hemorrhage or midline shift.", "negation_status": "Negated"},
    {"sentence": "No abnormal extraaxial fluid collections.", "negation_status": "Negated"},
    {"sentence": "The orbits are unremarkable in appearance.", "negation_status": "Affirmed"},
    {"sentence": "There is trace mucosal thickening within the ethmoid sinuses.", "negation_status": "Affirmed"},
    {"sentence": "Mastoid air cells are clear.", "negation_status": "Affirmed"},
    {"sentence": "There are no suspicious focal lesions of the bony calvarium or soft tissues of the scalp.", "negation_status": "Negated"},
    {"sentence": "Pituitary mass measuring 2.0 x 2.0 x 1.4 cm in size", "negation_status": "Affirmed"},
    {"sentence": "consistent with patient's clinical history of macroadenoma", "negation_status": "Affirmed"},
    {"sentence": "with expansion of the sella and suprasellar extension", "negation_status": "Affirmed"},
    {"sentence": "with mass effect on the right greater than left optic chiasm", "negation_status": "Affirmed"},
    {"sentence": "and cisternal segment of the right optic nerve", "negation_status": "Affirmed"},
    {"sentence": "and probable invasion into the medial aspect of the left and likely right cavernous sinuses", "negation_status": "Affirmed"},
    {"sentence": "with normal caliber cavernous carotid flow voids.", "negation_status": "Affirmed"},
    {"sentence": "There is cystic change and/or necrosis within the central and right lateral aspect of the mass.", "negation_status": "Affirmed"},
    {"sentence": "Elevated PSA.", "negation_status": "Affirmed"},
    {"sentence": "Enlarged prostate.", "negation_status": "Affirmed"},
    {"sentence": "History of prostate cancer", "negation_status": "Affirmed"},
    {"sentence": "20 mL of MultiHance was administered per protocol", "negation_status": "Affirmed"},
    {"sentence": "3T MRI with coronal T2; large FOV axial T2 3-D gradient echo; axial T1 and high-resolution T2, high b-value DWI and ADC sequences; dynamic axial T1 fat-sat post contrast. Multiparametric evaluation was performed on proprietary 3-D fusion software.", "negation_status": "Affirmed"},
    {"sentence": "Gas within rectum causes the susceptibility artifact on diffusion weighted sequences.", "negation_status": "Affirmed"},
    {"sentence": "Transitional Zone: Foci of low signal intensity seen in the posterior aspect of the transitional zone at the level of the mid gland towards the apex measuring 0.9 cm on the left and 0.7 cm on the right (series 8 image 9) with associated early enhancement (series 7 image 19) and possible restricted diffusion (series 11 and 10 image 10). Findings may represent neoplastic foci. Biopsy can be performed as clinically indicated.", "negation_status": "Affirmed"},
    {"sentence": "Peripheral Zone: Low signal intensity foci seen in the posterior aspect of the peripheral zone at the level of the mid gland toward the apex measuring 0.9 cm on the left and 0.9 cm on the right (series 8 image 9) with associated early enhancement (series 17 image 10) and possible restricted diffusion (areas 10 and 11 image 10). Findings are concerning for neoplastic foci. Biopsy can be performed as clinically indicated.", "negation_status": "Affirmed"},
    {"sentence": "Seminal Vesicles: No low signal intensity focus, restricted diffusion, early enhancement is seen in the seminal vesicles.", "negation_status": "Negated"},
    {"sentence": "Extracapsular Extension: Fat planes along the pseudocapsule of the prostate and neurovascular bundles are preserved.", "negation_status": "Affirmed"},
    {"sentence": "Pelvis: No lymphadenopathy is seen. No aggressive bony lesions are identified. Moderate to severe cartilage thinning is present in the left hip joint with subchondral cystic changes in acetabulum.", "negation_status": "Negated"},
    {"sentence": "1. Gas within rectum causes susceptibility artifact on diffusion weighted sequences.", "negation_status": "Affirmed"},
    {"sentence": "2. Enlarged prostate.", "negation_status": "Affirmed"},
    {"sentence": "3. Foci of low signal intensity and early enhancement and possible restricted diffusion in the posterior aspect of the transitional zone on the left and right at the level of the mid gland may represent neoplastic foci. Biopsy can be performed as clinically indicated.", "negation_status": "Affirmed"},
    {"sentence": "4. Foci of low signal intensity and early enhancement and possible restricted diffusion in the posterior aspect of the peripheral zone on the left and right at the level of the mid gland may represent neoplastic foci. Biopsy can be performed as clinically indicated.", "negation_status": "Affirmed"},
    {"sentence": "5. No seminal vesicle or extracapsular extension.", "negation_status": "Negated"},
    {"sentence": "6. No lymphadenopathy or aggressive bony lesions.", "negation_status": "Negated"},
    {"sentence": "7. Moderate to severe cartilage thinning in the left hip joint", "negation_status": "Affirmed"},
    {"sentence": "Work related injury on September 21, 2015, assess for traumatic tear left rotator cuff with superior shoulder pain and weakness.", "negation_status": "Not Negated"},
    {"sentence": "Axial PD FS, coronal PD FS and PD, sagittal T1 and PD FS imaging is performed through the left shoulder without contrast.", "negation_status": "Not Negated"},
    {"sentence": "ROTATOR CUFF: There is mild distal insertional tendinosis with minimal articular sided fraying of the distal aspect of the supraspinatus tendon. There is a 3 mm low-grade longitudinal interstitial tear involving the supraspinatus tendon at the distal attachment site seen on image 12 of series 7. There is no high-grade or fullthickness tear and no retraction. The infraspinatus tendon is normal. There is a longitudinal interstitial tear noted along the superior margin of the subscapularis tendon. No full-thickness tear or retraction noted.", "negation_status": "Not Negated"},
    {"sentence": "MUSCLES: The cuff musculature demonstrates minimal loss of muscle bulk and minimal grade 1 fatty infiltration of the subscapularis, infraspinatus and teres minor muscles.", "negation_status": "Not Negated"},
    {"sentence": "BICEPS: There is mild tendinosis of the proximal long head biceps tendon.", "negation_status": "Not Negated"},
    {"sentence": "SUBACROMIAL / SUBDELTOID BURSA: There is mild bursitis.", "negation_status": "Not Negated"},
    {"sentence": "ACROMION / AC JOINT: There is marrow edema within the distal clavicle. There is a small AC joint effusion with mild pericapsular edema. No elevation of the distal clavicle and no fracture. The coracoclavicular ligaments are intact. There is a mild type II acromial configuration and minimal lateral downsloping of the acromion. No subacromial spurring.", "negation_status": "Not Negated"},
    {"sentence": "GLENOHUMERAL JOINT / LABRUM: There is an extensive tear of the superior labrum extending from anterior to posterior with undermining of the long head biceps anchor consistent with a type II SLAP lesion. There is low-grade chondral thinning throughout the glenohumeral joint. No Bankart lesion noted. A small glenohumeral joint effusion is present. There is no intra-articular body.", "negation_status": "Not Negated"},
    {"sentence": "BONE MARROW: No fracture or malalignment.", "negation_status": "Negated"},
    {"sentence": "There is mild supraspinatus tendinosis with minimal articular sided fraying of the distal tendon and a 3 mm low grade interstitial tear at the distal attachment site.", "negation_status": "Not Negated"},
    {"sentence": "There is tendinosis and a low-grade longitudinal interstitial tear noted along the superior margin of the subscapularis tendon.", "negation_status": "Not Negated"},
    {"sentence": "There is a type II SLAP lesion and mild tendinosis of the intra-articular portion of the long head biceps tendon.", "negation_status": "Not Negated"},
    {"sentence": "Mild subacromial subdeltoid bursitis.", "negation_status": "Not Negated"},
    {"sentence": "There is marrow edema within the distal clavicle. There is a small AC joint effusion with mild pericapsular edema. This may represent mild stress related change of the AC joint versus a grade 1 sprain of the AC joint. There is no elevation or fracture of the distal clavicle.", "negation_status": "Not Negated"},
    {"sentence": "There is no occult fracture or bone contusion. No malalignment of the osseous structures.", "negation_status": "Negated"},
    {"sentence": "The age of injury is indeterminate", "negation_status": "Negated"},
    {"sentence": "Dorsal right medial upper back pain for 10 weeks. Evaluate for degenerative disc disease.", "negation_status": "Not Negated"},
    {"sentence": "MRI of the thoracic spine was obtained on a 3 Tesla magnet with the following sequences: Axial T2, sagittal T1, T2, and STIR.", "negation_status": "Not Negated"},
    {"sentence": "There is straightening of the normal cervical lordosis on the localizer sequence.", "negation_status": "Not Negated"},
    {"sentence": "There is a normal thoracic kyphosis.", "negation_status": "Not Negated"},
    {"sentence": "There is mild disc desiccation from T2-3 through T9-10 with mild prevertebral spondylosis at T2-3.", "negation_status": "Not Negated"},
    {"sentence": "Vertebral body heights are well-maintained without compression fracture.", "negation_status": "Not Negated"},
    {"sentence": "There is no bone marrow edema or destructive bony lesions identified.", "negation_status": "Not Negated"},
    {"sentence": "There is mild diffuse congenital narrowing of the spinal canal.", "negation_status": "Not Negated"},
    {"sentence": "No paraspinal soft tissue mass.", "negation_status": "Not Negated"},
    {"sentence": "There is a well-circumscribed 8mm T2 hyperintense lesion within the right hepatic lobe most likely representing a hepatic cyst or hemangioma.", "negation_status": "Not Negated"},
    {"sentence": "T7-8: There is a focal 3 mm central disc protrusion which results in deformity of the ventral spinal cord and a mild spinal canal stenosis without definite cord signal abnormality. No significant neural foraminal narrowing.", "negation_status": "Not Negated"},
    {"sentence": "T8-9: There is a focal 2 mm right central disc protrusion which results in mild deformity of the right ventral thecal sac and cord without spinal canal stenosis or neural foraminal narrowing.", "negation_status": "Not Negated"},
    {"sentence": "T9-10: There is mild left facet hypertrophy without spinal canal or neural foraminal stenosis.", "negation_status": "Not Negated"},
    {"sentence": "Elsewhere within the thoracic spine, there is no significant posterior disc bulge, disc protrusion, spinal canal stenosis, or neural foraminal narrowing.", "negation_status": "Not Negated"},
    {"sentence": "8mm well-circumscribed T2 hyperintense lesion within the right hepatic lobe, most likely representing a hepatic cyst or less likely hemangioma. This could be confirmed with abdominal ultrasound.", "negation_status": "Not Negated"},
    {"sentence": "Assess right wrist pain. Pain is diffuse. Status post fracture of the distal radius status post fall.", "negation_status": "Not Negated"},
    {"sentence": "None available.", "negation_status": "Negated"},
    {"sentence": "None utilized.", "negation_status": "Negated"},
    {"sentence": "Sagittal T1, sagittal STIR, coronal PD, coronal PD fat-sat, coronal 2-D gradient echo, axial PD fat-sat.", "negation_status": "Not Negated"},
    {"sentence": "FLUID: Moderate amount of fluid in the radiocarpal and midcarpal wrist compartments.", "negation_status": "Not Negated"},
    {"sentence": "JOINT ALIGNMENT: Mild dorsal angulation of the distal radius reflective of the fracture.", "negation_status": "Not Negated"},
    {"sentence": "CARTILAGE: Intact chondral surfaces.", "negation_status": "Not Negated"},
    {"sentence": "LIGAMENTS", "negation_status": "Not Negated"},
    {"sentence": "TFCC: Intact central and radial portions. There is edema in the peripheral attachments of the TFCC to the ulnar styloid process.", "negation_status": "Not Negated"},
    {"sentence": "Scapholunate (SL): Evidence of edema in the central and volar aspect of the ligament. Edema extends into the volar radiocarpal ligaments. The pattern is reflective of a volar injury and partial-thickness tear in this region. There is no complete tear. There is no DISI deformity.", "negation_status": "Not Negated"},
    {"sentence": "Lunotriquetral (LT): No evidence of a tear.", "negation_status": "Not Negated"},
    {"sentence": "EXTENSOR TENDONS: Moderate extensor carpi ulnaris tendinosis. There is fluid reflective of tenosynovitis in the second and third extensor compartments as well along the region of the extensor digitorum tendons.", "negation_status": "Not Negated"},
    {"sentence": "CARPAL TUNNEL: No compressive mass within the carpal tunnel.", "negation_status": "Not Negated"},
    {"sentence": "GUYON'S CANAL: No compressive mass.", "negation_status": "Not Negated"},
    {"sentence": "BONE MARROW: Evidence of an occult fracture of the distal radius. There is a transverse fracture line with associated prominent edema. There is mild dorsal angulation.", "negation_status": "Not Negated"},
    {"sentence": "1. Evidence of edema in the central as well as the volar aspect of the scapholunate ligament. Edema extends into the volar radiocarpal ligaments. The pattern is reflective of a volar injury and partial-thickness tear in this region. There is no complete tear. There is no DISI deformity", "negation_status": "Not Negated"},
    {"sentence": "2. Evidence of an occult fracture of the distal radius. There is a transverse fracture line with associated edema. There is mild dorsal angulation.", "negation_status": "Not Negated"},
    {"sentence": "3. Moderate extensor carpi ulnaris tendinosis. There is fluid reflective of tenosynovitis in the second and third extensor compartments as well along the region of the extensor digitorum tendons.", "negation_status": "Not Negated"},
]

# Print the annotated data
for sentence_info in annotated_data:
    print(sentence_info)
# Out:
# {'sentence': 'Left neck and shoulder pain for 2 months', 'negation_status': 'Affirmed'}
# {'sentence': 'MRI of the cervical spine was obtained with the following sequences: Axial GRE, sagittal T1, T2, and STI', 'negation_status': 'Affirmed'}
# {'sentence': 'ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to muscular spasm.', 'negation_status': 'Affirmed'}
# {'sentence': 'DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral spondylosis.', 'negation_status': 'Affirmed'}
# {'sentence': 'CORD: Spinal cord is normal in caliber and signal intensity. Cerebellar tonsils are normally located.', 'negation_status': 'Affirmed'}
# {'sentence': 'BONE MARROW: No destructive bony lesions. There is low T1 signal intensity within the bone marrow surrounding the left C4-5 facet joint which may be reactive to facet arthropathy.', 'negation_status': 'Negated'}
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, SimpleRNN
from sklearn.model_selection import train_test_split

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
sentences = [entry['sentence'] for entry in annotated_data]
status = [entry['negation_status'] for entry in annotated_data]

detect_negation = lambda input_str: 1 if input_str.lower() == 'affirmed' else (0 if input_str.lower() == 'negated' else 1)
labels = list(map(detect_negation, status))

# %%
# Tokenize and preprocess the data
tokenizer = Tokenizer()  # Initialize a tokenizer
tokenizer.fit_on_texts(sentences)  # Fit the tokenizer on the input sentences to build vocabulary
sequences = tokenizer.texts_to_sequences(sentences)  # Convert input sentences to sequences of integers
max_sequence_length = max(len(seq) for seq in sequences)  # Find the maximum sequence length
X = pad_sequences(sequences, maxlen=max_sequence_length)  # Pad sequences to have a uniform length
y = np.array(labels)  # Convert labels to a NumPy array

# Define the RNN model
vocab_size = len(tokenizer.word_index) + 1  # Get the vocabulary size
embedding_dim = 32  # Dimensionality of word embeddings
rnn_units = 64  # Number of units in the RNN layer

model = Sequential()  # Initialize a sequential model
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_sequence_length))  # Add an embedding layer
model.add(SimpleRNN(units=rnn_units))  # Add a SimpleRNN layer
model.add(Dense(1, activation='sigmoid'))  # Add a dense output layer with sigmoid activation for binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model (replace with your data)
model.fit(X, y, epochs=10, batch_size=2)  # Train the model for 10 epochs with a batch size of 2
model.save('models/negation_model.h5')  # Save the trained model to a file
# Out:
# Epoch 1/10
# 154/154 [==============================] - 3s 15ms/step - loss: 0.6072 - accuracy: 0.6948
# Epoch 2/10
# 154/154 [==============================] - 2s 16ms/step - loss: 0.4852 - accuracy: 0.7403
# Epoch 3/10
# 154/154 [==============================] - 2s 15ms/step - loss: 0.4308 - accuracy: 0.7922
# Epoch 4/10
# 154/154 [==============================] - 2s 15ms/step - loss: 0.2968 - accuracy: 0.8701
# Epoch 5/10
# 154/154 [==============================] - 2s 15ms/step - loss: 0.1954 - accuracy: 0.9253
# Epoch 6/10
# 154/154 [==============================] - 2s 16ms/step - loss: 0.1179 - accuracy: 0.9481
# Epoch 7/10
# 154/154 [==============================] - 2s 15ms/step - loss: 0.0675 - accuracy: 0.9773
# Epoch 8/10
# 154/154 [==============================] - 3s 19ms/step - loss: 0.0307 - accuracy: 0.9935
# Epoch 9/10
# 154/154 [==============================] - 3s 21ms/step - loss: 0.0202 - accuracy: 0.9968
# Epoch 10/10
# ...

# %%
#load model
model = tf.keras.models.load_model('models/negation_model.h5')

# %%
# Inference
def predict(new_sentence):
    new_sequence = tokenizer.texts_to_sequences([new_sentence])
    new_X = pad_sequences(new_sequence, maxlen=max_sequence_length)
    prediction = model.predict(new_X)
    
    if prediction[0][0] >= 0.5:
        print("Affirmed" , f"| Confidence:{100*prediction[0][0]:.4f}%")
    else:
        print("Negated" , f"| Confidence:{100-prediction[0][0]:.4f}%")

# %%
predict("No abnormal extraaxial fluid collections.")
# Out:
# 1/1 [==============================] - 0s 159ms/step
# Negated | Confidence:99.9970%

# %%
predict("ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to muscular spasm. DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral spondylosis. CORD: Spinal cord is normal in caliber and signal int nsit. Cerebellar tonsils are normally located. BONE MARROW: No destructive bony lesions. There is low T1 signal intensity within the bone marrow surrounding the left C4-5 facet joint which may be reactive to facet arthropathy. ")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Negated | Confidence:99.9871%

# %%
print(text)
# Out:
# [ NationalRad Sample Neuroradiology Report ]
#
# Imaging Center
# 123 Main Street
# Anywhere, USA 01234
# Phone 123.456.7890
# Fax 123.456.7890
#
# PATIENT:
# DOB:
# FILE #:
# PHYSICIAN:
# EXAM:
# DATE:
#
# JOHN SMITH
# 5/5/1955
# 12345
# REFERRING
# MRI CERVICAL SPINE
# 1/1/2011
#
# CLINICAL INFORMATION
#
# Left neck and shoulder pain for 2 months
#
# COMPARISON
#
# None
#
# CONTRAST
#
# None given
#
# TECHNIQUE
#
# MRI of the cervical spine was obtained with the following sequences: Axial GRE, sagittal T1, T2, and STIR.
#
# FINDINGS
#
# ALIGNMENT: There is straightening of the normal cervical lordosis which may be positional or related to
# muscular spasm.
#
# DISCS: There is moderate to severe disc space narrowing from C4-5 through C6-7 with prominent prevertebral
# spondylosis.
#
# CORD: Spinal cord is normal in caliber and signal intensity. Cerebellar tonsils are normally located.
#
# ...

# %%
predict("No disc osteophyte complex, spinal canal stenosis, or neural foraminal narrowing.")
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Negated | Confidence:99.9592%
